# %%
# Import libraries section

import json
import numpy as np
import pandas as pd
import plotly
import psycopg2
import seaborn as sns
import spotipy
import tensorflow as tf

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, scale
from spotipy.oauth2 import SpotifyClientCredentials
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential

# %%
client_credentials_manager = SpotifyClientCredentials(client_id='64c7e99146a749da88cbad6d9b55183c', client_secret='48bb5ebd778f4223a2b0cdd3e9a3a66d')
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
conn = psycopg2.connect("dbname='phmcuozt' user='phmcuozt' host='drona.db.elephantsql.com' password='Hl4xzpVOZxiQ9af4kH5bavoEHIx7z3hn'")
conn.close()

# %%
songs = pd.read_sql_query('SELECT * FROM spotify_table', conn, index_col='index')
songs = songs.drop(labels='Unnamed: 0')
songs.head()
# Out:
#        Unnamed: 0        artist_name                        track_name  \
# index
# 0               0        Miley Cyrus               Party In The U.S.A.
# 1               1           Kid Cudi          Day 'N' Nite (nightmare)
# 2               2           Owl City                         Fireflies
# 3               3  Cage The Elephant      Ain't No Rest for the Wicked
# 4               4           Kid Cudi  Pursuit Of Happiness (Nightmare)
#
#                      track_id  popularity  danceability  energy  key  \
# index
# 0      5Q0Nhxo0l2bP3pNjpGJwV1          74         0.652   0.698   10
# 1      5FEXPoPnzueFJQCPRIrC3c          74         0.871   0.440   11
# 2      3DamFFqW32WihKkTVlwTYQ          80         0.513   0.661    3
# 3      3Pzh926pXggbMe2ZpXyMV7          74         0.634   0.849    0
# 4      5iSEsR6NKjlC9SrIJkyL3k          72         0.630   0.605    0
#
#        loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# index
# 0        -4.667     0       0.0420       0.00112          0.000115    0.0886
# 1        -6.250     0       0.0761       0.49900          0.000004    0.1140
# 2        -6.800     1       0.0439       0.02740          0.000000    0.1180
# 3        -7.075     1       0.1050       0.04380          0.000000    0.3630
# 4        -8.951     1       0.0414       0.48400          0.000093    0.2980
#
#        valence    tempo  duration_ms  time_signature
# index
# 0        0.470   96.021       202067               4
# 1        0.799  137.996       221267               4
# 2        0.461  180.119       228347               4
# 3        0.919  156.004       175493               4
# 4        0.266  115.277       295293               4

# %%
conn = psycopg2.connect("dbname='phmcuozt' user='phmcuozt' host='drona.db.elephantsql.com' password='Hl4xzpVOZxiQ9af4kH5bavoEHIx7z3hn'")

# %%
import pandas as pd
songs = pd.read_sql_query('SELECT * FROM spotify_table', conn, index_col='index')

# %%
songs_elef
# Out:
#        Unnamed: 0        artist_name  \
# index
# 0               0        Miley Cyrus
# 1               1           Kid Cudi
# 2               2           Owl City
# 3               3  Cage The Elephant
# 4               4           Kid Cudi
# ...           ...                ...
# 58218        1930        Hank Mobley
# 58219        1931         Greg Brown
# 58220        1932       Bad Religion
# 58221        1933              Phish
# 58222        1934                Dio
#
#                                               track_name  \
# index
# 0                                    Party In The U.S.A.
# 1                               Day 'N' Nite (nightmare)
# 2                                              Fireflies
# 3                           Ain't No Rest for the Wicked
# 4                       Pursuit Of Happiness (Nightmare)
# ...                                                  ...
# 58218  Split Feelin's - Remastered 1999/Rudy Van Geld...
# 58219                                     Laughing River
# 58220                                            Entropy
# 58221                                           Lawn Boy
# 58222                                          Hey Angel
#
#                      track_id  popularity  danceability  energy  key  \
# index
# 0      5Q0Nhxo0l2bP3pNjpGJwV1          74         0.652   0.698   10
# 1      5FEXPoPnzueFJQCPRIrC3c          74         0.871   0.440   11
# 2      3DamFFqW32WihKkTVlwTYQ          80         0.513   0.661    3
# 3      3Pzh926pXggbMe2ZpXyMV7          74         0.634   0.849    0
# 4      5iSEsR6NKjlC9SrIJkyL3k          72         0.630   0.605    0
# ...                       ...         ...           ...     ...  ...
# 58218  3V3r5GlxyDjubv9TiZuw1s          31         0.578   0.620    7
# 58219  3c3gpi1zmCc7Wz8w3D0xWF          27         0.331   0.337    5
# 58220  3pljz8rcppyUQIhC1emPye          32         0.368   0.989    8
# 58221  4c0faWa7yhMMyQkdDDtvcr          25         0.626   0.280    4
# 58222  5Qz24iSE8LHJE59th8ZLXV          26         0.383   0.830    2
#
#        loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# index
# 0        -4.667     0       0.0420      0.001120          0.000115    0.0886
# 1        -6.250     0       0.0761      0.499000          0.000004    0.1140
# 2        -6.800     1       0.0439      0.027400          0.000000    0.1180
# 3        -7.075     1       0.1050      0.043800          0.000000    0.3630
# 4        -8.951     1       0.0414      0.484000          0.000093    0.2980
# ...         ...   ...          ...           ...               ...       ...
# 58218    -9.269     0       0.0407      0.750000          0.002620    0.0605
# 58219   -12.338     1       0.0366      0.401000          0.000352    0.1080
# 58220    -3.876     1       0.1250      0.000226          0.000000    0.0530
# 58221   -16.641     1       0.0388      0.596000          0.016200    0.1090
# 58222    -9.651     1       0.0316      0.000406          0.000907    0.0978
#
#        valence    tempo  duration_ms  time_signature
# index
# 0        0.470   96.021       202067               4
# 1        0.799  137.996       221267               4
# 2        0.461  180.119       228347               4
# 3        0.919  156.004       175493               4
# 4        0.266  115.277       295293               4
# ...        ...      ...          ...             ...
# 58218    0.748  115.544       295680               4
# 58219    0.439  201.367       259520               4
# 58220    0.428  153.716       143733               4
# 58221    0.342  106.016       151800               3
# 58222    0.438   87.860       300133               4
#
# [58223 rows x 18 columns]
