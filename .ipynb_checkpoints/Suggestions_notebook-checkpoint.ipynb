# %%
# Import libraries section

import json
import numpy as np
import pandas as pd
import plotly
import psycopg2
import seaborn as sns
import spotipy
import tensorflow as tf

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, scale
from spotipy.oauth2 import SpotifyClientCredentials
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential

# %%
client_credentials_manager = SpotifyClientCredentials(client_id='64c7e99146a749da88cbad6d9b55183c', client_secret='48bb5ebd778f4223a2b0cdd3e9a3a66d')
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
# plotly.tools.set_credencials_file(username='CodingDuckmx', api_key='BJDTaHirN1qxM6uaTXhS')
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
connection = psycopg2.connect(user='postgres',
                                    password='9853465584',
                                    host='127.0.0.1',
                                    port='5432',
                                    database='spotify')

songs = pd.read_sql_query('SELECT * FROM songs', connection, index_col='id')

users = pd.read_sql_query('SELECT * FROM users', connection, index_col='id')

connection.close()

# %%
print(songs.shape, users.shape)
display(songs.head())
display(users.head())
# Out:
# (4175, 19) (54, 3)
#                    song_id                                          song_name  \
# id
# 1   7w87IxuO7BDcJ3YUqCyMTT                                    Pumped Up Kicks
# 2   5pgnhdKnYTt4MDAitK0yB1  Symphony No. 6 in F Major, Op. 68 "Pastoral": ...
# 3   76n0kW0cXIy9Nz8AuSEAB3                                 Sin Ti No Sé Vivir
# 4   7CUYHcu0RnbOnMz4RuN07w                 Despacito (Featuring Daddy Yankee)
# 5   3S4px9f4lceWdKf0gWciFu                                      Cheap Thrills
#
#                  artists                                              album  \
# id
# 1      Foster The People                                            Torches
# 2   Ludwig van Beethoven  Beethoven: Symphony No. 6 in F Major, Op. 68 "...
# 3     Los Angeles Azules                               20 Kilates 20 Éxitos
# 4             Luis Fonsi                 Despacito (Featuring Daddy Yankee)
# 5                    Sia                    This Is Acting (Deluxe Version)
#
# ...

# %%
encoder = LabelEncoder()

numerical_features = ['acousticness','danceability','duration_ms',
                                'energy','instrumentalness','song_key', 'liveness',
                                'loudness','song_mode','speechiness', 'tempo',
                                'time_signature','valence']

scaled_data = scale(songs[numerical_features])

encoded = encoder.fit_transform(songs['artists'])

songs[numerical_features] = scaled_data
songs['artists_encoded'] = encoded

songs.head()
# Out:
#                    song_id                                          song_name  \
# id
# 1   7w87IxuO7BDcJ3YUqCyMTT                                    Pumped Up Kicks
# 2   5pgnhdKnYTt4MDAitK0yB1  Symphony No. 6 in F Major, Op. 68 "Pastoral": ...
# 3   76n0kW0cXIy9Nz8AuSEAB3                                 Sin Ti No Sé Vivir
# 4   7CUYHcu0RnbOnMz4RuN07w                 Despacito (Featuring Daddy Yankee)
# 5   3S4px9f4lceWdKf0gWciFu                                      Cheap Thrills
#
#                  artists                                              album  \
# id
# 1      Foster The People                                            Torches
# 2   Ludwig van Beethoven  Beethoven: Symphony No. 6 in F Major, Op. 68 "...
# 3     Los Angeles Azules                               20 Kilates 20 Éxitos
# 4             Luis Fonsi                 Despacito (Featuring Daddy Yankee)
# 5                    Sia                    This Is Acting (Deluxe Version)
#
# ...

# %%
features = ['artists_encoded','acousticness','danceability','duration_ms',
                                'energy','instrumentalness','song_key', 'liveness',
                                'loudness','song_mode','speechiness', 'tempo',
                                'time_signature','valence']
songs[features] = songs[features].astype(float)
songs_features = songs[features].astype(float)
songs_features.head()
# Out:
#     artists_encoded  acousticness  danceability  duration_ms    energy  \
# id
# 1             941.0     -0.493713      0.978542     0.017103  0.366405
# 2            1655.0      1.981081     -1.473638     0.480118 -2.158018
# 3            1632.0      0.022372      0.453501    -0.087262 -0.822930
# 4            1657.0     -0.303576      0.537031    -0.056099  0.723983
# 5            2428.0     -0.788877      0.352073    -0.162261  0.319764
#
#     instrumentalness  song_key  liveness  loudness  song_mode  speechiness  \
# id
# 1          -0.083364 -0.069317 -0.576139  0.483635  -1.407886    -0.480012
# 2           1.652660 -0.069317  0.875338 -2.841720   0.710285    -0.349013
# 3          -0.481852 -0.908959 -0.435407  0.474280   0.710285    -0.415311
# 4          -0.481852 -0.908959 -0.387116  0.685814   0.710285     0.468933
# 5          -0.476897  0.210564 -0.609943  0.529646  -1.407886     0.125460
#
#        tempo  time_signature   valence
# id
# ...

# %%
#  Product of the vectors.

knn = Sequential()
knn.add(Dense(input_shape=(songs_features.shape[1],),
       units=songs.shape[0],
       activation='linear',
       use_bias=False))

knn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 4175)              58450
# ...
# Total params: 58,450
# Trainable params: 58,450
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Normalize the vectors

def normalize(vectors):
    
    norm_vectors = np.linalg.norm(vectors, axis=1, keepdims=True)
    return (vectors / norm_vectors)

# %%
norm_songs_features = normalize(songs_features)
norm_songs_features.head()
# Out:
#     artists_encoded  acousticness  danceability  duration_ms    energy  \
# id
# 1          0.999995     -0.000525      0.001040     0.000018  0.000389
# 2          0.999996      0.001197     -0.000890     0.000290 -0.001304
# 3          0.999999      0.000014      0.000278    -0.000053 -0.000504
# 4          0.999998     -0.000183      0.000324    -0.000034  0.000437
# 5          0.999999     -0.000325      0.000145    -0.000067  0.000132
#
#     instrumentalness  song_key  liveness  loudness  song_mode  speechiness  \
# id
# 1          -0.000089 -0.000074 -0.000612  0.000514  -0.001496    -0.000510
# 2           0.000999 -0.000042  0.000529 -0.001717   0.000429    -0.000211
# 3          -0.000295 -0.000557 -0.000267  0.000291   0.000435    -0.000254
# 4          -0.000291 -0.000549 -0.000234  0.000414   0.000429     0.000283
# 5          -0.000196  0.000087 -0.000251  0.000218  -0.000580     0.000052
#
#        tempo  time_signature   valence
# id
# ...

# %%
# change the weights to the original matrix of features (of songs).

knn.set_weights([np.array(norm_songs_features.T)])
knn.get_weights()
# Out:
# [array([[ 9.9999511e-01,  9.9999553e-01,  9.9999875e-01, ...,
#           9.9999940e-01,  9.9999887e-01,  9.9999940e-01],
#         [-5.2466546e-04,  1.1970224e-03,  1.3708568e-05, ...,
#          -4.0849688e-04, -2.9663154e-04,  5.1274884e-04],
#         [ 1.0398910e-03, -8.9041149e-04,  2.7788038e-04, ...,
#           1.2362392e-04,  6.5584638e-04,  1.6165987e-04],
#         ...,
#         [ 2.9124445e-04,  6.5439078e-04, -7.5864879e-04, ...,
#          -1.6161753e-04, -4.3512299e-04,  7.1024922e-05],
#         [ 2.2397780e-04,  1.2734937e-04,  1.2914454e-04, ...,
#           9.9229765e-05,  1.3314208e-04,  7.2278468e-05],
#         [ 2.2273082e-03, -2.7420075e-04,  8.4943452e-04, ...,
#           1.3015667e-04,  3.8835342e-04,  7.9241974e-05]], dtype=float32)]

# %%
# Prediction time

random_choice = np.random.randint(1,songs.shape[0]+1)

sample_song = songs.loc[random_choice]
print('Artist:', sample_song[2])
print('Song name:', sample_song[1])
# Out:
# Artist: Jade Bird
# Song name: I Get No Joy

# %%
prediction = knn.predict(songs_features.loc[random_choice].values.reshape(1,songs_features.shape[1]))

# %%
ten_most_similar_songs = songs.loc[prediction.argsort()[0][-10:]]
ten_most_similar_songs[['song_id','song_name','artists','album']]
# Out:
#                      song_id        song_name                     artists  \
# id
# 4092  3wfujdbamR3Z46F4xav7LM            Drive                    The Cars
# 3726  57hO2DGhBI2BbqCjVxpJcr       Ever After                       dvine
# 1805  2CEgGE6aESpnmtfiZwYlbV         Dynamite                   Taio Cruz
# 3272  2Zw8XSF8vSPeDHUNCmjLgi      Rebel Rebel                   Seu Jorge
# 2546  4KQlPYIchV2VWo8SaWOs9C        Promenade  Street Sweeper Social Club
# 4167  0E9ZjEAyAwOXZ7wJC0PD33       In My Mind                      Dynoro
# 3483  0LQW3QOPjECHV9y8y47OOT  Lebanese Blonde        Thievery Corporation
# 3481  28YMQj2P0m3dvJqgjxLkEq    Saint Honesty              Sara Bareilles
# 4020  39UWlEnYolv3LfQoEYqJIn            Tiger                    Das Kope
# 2801  2pU5gIulfIITLJw6F38IMK     Call My Name                I'm With Her
#
#                                              album
# id
# 4092                                Heartbeat City
# ...

# %%
artists_photos_urls = []

for i in range(10):
    artists_photos_urls.append(sp.artist(sp.tracks(ten_most_similar_songs['song_id'])['tracks'][i]['artists'][0]['id'])['images'][0]['url'])

ten_most_similar_songs['artists_photos_urls'] = artists_photos_urls

# %%
# 30 sec of song

seconds_of_song_urls = []

for i in range(10):
    seconds_of_song_urls.append(sp.tracks(ten_most_similar_songs['song_id'])['tracks'][i]['preview_url'])

ten_most_similar_songs['sample_sound_url'] = seconds_of_song_urls

# %%
ten_most_similar_songs
# Out:
#                      song_id        song_name                     artists  \
# id
# 4092  3wfujdbamR3Z46F4xav7LM            Drive                    The Cars
# 3726  57hO2DGhBI2BbqCjVxpJcr       Ever After                       dvine
# 1805  2CEgGE6aESpnmtfiZwYlbV         Dynamite                   Taio Cruz
# 3272  2Zw8XSF8vSPeDHUNCmjLgi      Rebel Rebel                   Seu Jorge
# 2546  4KQlPYIchV2VWo8SaWOs9C        Promenade  Street Sweeper Social Club
# 4167  0E9ZjEAyAwOXZ7wJC0PD33       In My Mind                      Dynoro
# 3483  0LQW3QOPjECHV9y8y47OOT  Lebanese Blonde        Thievery Corporation
# 3481  28YMQj2P0m3dvJqgjxLkEq    Saint Honesty              Sara Bareilles
# 4020  39UWlEnYolv3LfQoEYqJIn            Tiger                    Das Kope
# 2801  2pU5gIulfIITLJw6F38IMK     Call My Name                I'm With Her
#
#                                              album  danceability    energy  \
# id
# ...

# %%
extendend_result = ten_most_similar_songs.append(dict(sample_song),ignore_index=True)
extendend_result['hue'] = 'recomendation'
extendend_result.iloc[10,-1] = 'base'
extendend_result = extendend_result[['acousticness','danceability','duration_ms',
                                'energy','instrumentalness','song_key', 'liveness',
                                'loudness','song_mode','speechiness', 'tempo',
                                'time_signature','valence','hue']]

# %%
sns.pairplot(extendend_result, hue = 'hue')
# Out:
# C:\Users\jcm\Anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning:
#
# Data must have variance to compute a kernel density estimate.
#
# C:\Users\jcm\Anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning:
#
# Data must have variance to compute a kernel density estimate.
#
# C:\Users\jcm\Anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning:
#
# Data must have variance to compute a kernel density estimate.
#
# C:\Users\jcm\Anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning:
#
# Data must have variance to compute a kernel density estimate.
#
# C:\Users\jcm\Anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning:
#
# Data must have variance to compute a kernel density estimate.
#
# C:\Users\jcm\Anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning:
#
# Data must have variance to compute a kernel density estimate.
#
# ...

# %%
# Out:
#     acousticness  danceability  duration_ms    energy  instrumentalness  \
# 0      -0.557091      0.077620    -0.015691 -0.037814         -0.477036
# 1      -0.608398      0.745854    -0.058957  0.782284          2.408055
# 2      -0.919890      1.085937    -0.220399  0.650135         -0.481852
# 3       1.824143      0.877114    -0.595566 -1.390391         -0.481852
# 4      -0.475604      1.002408    -0.549847  0.533534         -0.481426
# 5      -0.400153      0.745854    -0.336322  0.599608         -0.481814
# 6      -0.203981      1.437953     0.318130  0.770623          2.456567
# 7       1.618916      0.226779     0.242340 -1.627481         -0.481785
# 8       0.731612     -0.161035    -0.359624 -0.850137          0.228497
# 9       1.495176      0.202914    -0.284265 -0.706329         -0.390720
# 10      0.167238      0.620560    -0.480735  0.413045         -0.481852
#
#     song_key  liveness  loudness  song_mode  speechiness     tempo  \
# ...
